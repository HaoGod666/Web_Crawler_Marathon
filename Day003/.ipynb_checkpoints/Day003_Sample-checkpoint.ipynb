# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"22161710687","type":"PushEvent","actor":{"id":19583619,"login":"sambhav2612","display_login":"sambhav2612","gravatar_id":"","url":"https://api.github.com/users/sambhav2612","avatar_url":"https://avatars.githubusercontent.com/u/19583619?"},"repo":{"id":280470919,"name":"sambhav2612/sambhav2612","url":"https://api.github.com/repos/sambhav2612/sambhav2612"},"payload":{"push_id":10071144025,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"1fc91ad3c40bc964aa0ffe346de59587e5c245dc","before":"8dd6833df552a7bad2f6963c487681afbbb28c33","commits":[{"sha":"1fc91ad3c40bc964aa0ffe346de59587e5c245dc","author":{"email":"41898282+github-actions[bot]@users.noreply.github.com","name":"readme-bot"},"message":"Updated with Dev Metrics","distinct":true,"url":"https://api.github.com/repos/sambhav2612/sambhav2612/commits/1fc91ad3c40bc964aa0ffe346de59587e5c245dc"}]},"public":true,"created_at":"2022-06-04T15:47:46Z"},{"id":"22161710662","type":"PushEvent","actor":{"id":81525353,"login":"issimonwoods","display_login":"issimonwoods","gravatar_id":"","url":"https://api.github.com/users/issimonwoods","avatar_url":"https://avatars.githubusercontent.com/u/81525353?"},"repo":{"id":423818933,"name":"issimonwoods/blog","url":"https://api.github.com/repos/issimonwoods/blog"},"payload":{"push_id":10071144007,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"2b6f37df890d5a98efd0b1efb4363436b2f460dd","before":"f976d71f222eff01a8a04834b94f38ba87783fc2","commits":[{"sha":"2b6f37df890d5a98efd0b1efb4363436b2f460dd","author":{"email":"81525353+issimonwoods@users.noreply.github.com","name":"Simon Woods"},"message":"Archiving from Micro.blog.","distinct":true,"url":"https://api.github.com/repos/issimonwoods/blog/commits/2b6f37df890d5a98efd0b1efb4363436b2f460dd"}]},"public":true,"created_at":"2022-06-04T15:47:46Z"},{"id":"22161710666","type":"CreateEvent","actor":{"id":75322794,"login":"Hawk1430","display_login":"Hawk1430","gravatar_id":"","url":"https://api.github.com/users/Hawk1430","avatar_url":"https://avatars.githubusercontent.com/u/75322794?"},"repo":{"id":499869423,"name":"Hawk1430/Striver-60-Days-SDE-Sheet-Challenge","url":"https://api.github.com/repos/Hawk1430/Striver-60-Days-SDE-Sheet-Challenge"},"payload":{"ref":"main","ref_type":"branch","master_branch":"main","description":"60 Days Challenge","pusher_type":"user"},"public":true,"created_at":"2022-06-04T15:47:46Z"},{"id":"22161710660","type":"PushEvent","actor":{"id":105630721,"login":"jakegreen4587","display_login":"jakegreen4587","gravatar_id":"","url":"https://api.github.com/users/jakegreen4587","avatar_url":"https://avatars.githubusercontent.com/u/105630721?"},"repo":{"id":492730034,"name":"jakegreen4587/2","url":"https://api.github.com/repos/jakegreen4587/2"},"payload":{"push_id":10071144009,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"d4b0b7ff0debee26f4e9112660db21e143212b1f","before":"6ca3867b2e2cbe5023cee51ec9e4a1fe26716a9d","commits":[{"sha":"d4b0b7ff0debee26f4e9112660db21e143212b1f","author":{"email":"test@gmail.com","name":"test"},"message":"test","distinct":true,"url":"https://api.github.com/repos/jakegreen4587/2/commits/d4b0b7ff0debee26f4e9112660db21e143212b1f"}]},"public":true,"created_at":"2022-06-04T15:47:46Z"},{"id":"22161710635","type":"PushEvent","actor":{"id":57944288,"login":"eric891224","display_login":"eric891224","gravatar_id":"","url":"https://api.github.com/users/eric891224","avatar_url":"https://avatars.githubusercontent.com/u/57944288?"},"repo":{"id":496445167,"name":"eric891224/2022_CA_Final_Project","url":"https://api.github.com/repos/eric891224/2022_CA_Final_Project"},"payload":{"push_id":10071143996,"size":2,"distinct_size":2,"ref":"refs/heads/main","head":"fe581a9af9b4a61b5e0c94d39e86f960590dd452","before":"5670a0c4219ed3c63df70793b490e3ed7102a1b8","commits":[{"sha":"abb90b9388c8d3935d6e0edb419ac94d7426267d","author":{"email":"s96006730@gmail.com","name":"eric891224"},"message":"debug","distinct":true,"url":"https://api.github.com/rep ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '22161710687',
#   'type': 'PushEvent',
#   'actor': {'id': 19583619,
#    'login': 'sambhav2612',
#    'display_login': 'sambhav2612',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sambhav2612',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19583619?'},
#   'repo': {'id': 280470919,
#    'name': 'sambhav2612/sambhav2612',
#    'url': 'https://api.github.com/repos/sambhav2612/sambhav2612'},
#   'payload': {'push_id': 10071144025,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1fc91ad3c40bc964aa0ffe346de59587e5c245dc',
#    'before': '8dd6833df552a7bad2f6963c487681afbbb28c33',
#    'commits': [{'sha': '1fc91ad3c40bc964aa0ffe346de59587e5c245dc',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'readme-bot'},
#      'message': 'Updated with Dev Metrics',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sambhav2612/sambhav2612/commits/1fc91ad3c40bc964aa0ffe346de59587e5c245dc'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710662',
#   'type': 'PushEvent',
#   'actor': {'id': 81525353,
#    'login': 'issimonwoods',
#    'display_login': 'issimonwoods',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/issimonwoods',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81525353?'},
#   'repo': {'id': 423818933,
#    'name': 'issimonwoods/blog',
#    'url': 'https://api.github.com/repos/issimonwoods/blog'},
#   'payload': {'push_id': 10071144007,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2b6f37df890d5a98efd0b1efb4363436b2f460dd',
#    'before': 'f976d71f222eff01a8a04834b94f38ba87783fc2',
#    'commits': [{'sha': '2b6f37df890d5a98efd0b1efb4363436b2f460dd',
#      'author': {'email': '81525353+issimonwoods@users.noreply.github.com',
#       'name': 'Simon Woods'},
#      'message': 'Archiving from Micro.blog.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/issimonwoods/blog/commits/2b6f37df890d5a98efd0b1efb4363436b2f460dd'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710666',
#   'type': 'CreateEvent',
#   'actor': {'id': 75322794,
#    'login': 'Hawk1430',
#    'display_login': 'Hawk1430',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Hawk1430',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/75322794?'},
#   'repo': {'id': 499869423,
#    'name': 'Hawk1430/Striver-60-Days-SDE-Sheet-Challenge',
#    'url': 'https://api.github.com/repos/Hawk1430/Striver-60-Days-SDE-Sheet-Challenge'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': '60 Days Challenge',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710660',
#   'type': 'PushEvent',
#   'actor': {'id': 105630721,
#    'login': 'jakegreen4587',
#    'display_login': 'jakegreen4587',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jakegreen4587',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/105630721?'},
#   'repo': {'id': 492730034,
#    'name': 'jakegreen4587/2',
#    'url': 'https://api.github.com/repos/jakegreen4587/2'},
#   'payload': {'push_id': 10071144009,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd4b0b7ff0debee26f4e9112660db21e143212b1f',
#    'before': '6ca3867b2e2cbe5023cee51ec9e4a1fe26716a9d',
#    'commits': [{'sha': 'd4b0b7ff0debee26f4e9112660db21e143212b1f',
#      'author': {'email': 'test@gmail.com', 'name': 'test'},
#      'message': 'test',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jakegreen4587/2/commits/d4b0b7ff0debee26f4e9112660db21e143212b1f'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710635',
#   'type': 'PushEvent',
#   'actor': {'id': 57944288,
#    'login': 'eric891224',
#    'display_login': 'eric891224',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eric891224',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57944288?'},
#   'repo': {'id': 496445167,
#    'name': 'eric891224/2022_CA_Final_Project',
#    'url': 'https://api.github.com/repos/eric891224/2022_CA_Final_Project'},
#   'payload': {'push_id': 10071143996,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': 'fe581a9af9b4a61b5e0c94d39e86f960590dd452',
#    'before': '5670a0c4219ed3c63df70793b490e3ed7102a1b8',
#    'commits': [{'sha': 'abb90b9388c8d3935d6e0edb419ac94d7426267d',
#      'author': {'email': 's96006730@gmail.com', 'name': 'eric891224'},
#      'message': 'debug',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eric891224/2022_CA_Final_Project/commits/abb90b9388c8d3935d6e0edb419ac94d7426267d'},
#     {'sha': 'fe581a9af9b4a61b5e0c94d39e86f960590dd452',
#      'author': {'email': 's96006730@gmail.com', 'name': 'eric891224'},
#      'message': "Merge branch 'main' of github.com:eric891224/2022_CA_Final_Project",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eric891224/2022_CA_Final_Project/commits/fe581a9af9b4a61b5e0c94d39e86f960590dd452'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710654',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 86929735,
#    'name': 'Lombiq/Orchard',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard'},
#   'payload': {'push_id': 10071144004,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/feature/asyncscripts',
#    'head': '41e6daab43e8f4acbd0681c3e2f797978dce872e',
#    'before': '41e6daab43e8f4acbd0681c3e2f797978dce872e',
#    'commits': []},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '22161710655',
#   'type': 'PushEvent',
#   'actor': {'id': 85495935,
#    'login': 'xenxynon',
#    'display_login': 'xenxynon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xenxynon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/85495935?'},
#   'repo': {'id': 483961223,
#    'name': 'xenxynon/android_device_xiaomi_lavender',
#    'url': 'https://api.github.com/repos/xenxynon/android_device_xiaomi_lavender'},
#   'payload': {'push_id': 10071144006,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/arrow',
#    'head': 'd45595d2d0a9b4fb31a732ed570a7fe3a04a8065',
#    'before': '70db78683484c914ac07d7994aba192b18ef0dd1',
#    'commits': []},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710645',
#   'type': 'ForkEvent',
#   'actor': {'id': 106861457,
#    'login': 'Cycorevil',
#    'display_login': 'Cycorevil',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Cycorevil',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/106861457?'},
#   'repo': {'id': 441925385,
#    'name': 'LEGEND-OS/MUSIC-VC',
#    'url': 'https://api.github.com/repos/LEGEND-OS/MUSIC-VC'},
#   'payload': {'forkee': {'id': 499869426,
#     'node_id': 'R_kgDOHctm8g',
#     'name': 'MUSIC-Video',
#     'full_name': 'Cycorevil/MUSIC-Video',
#     'private': False,
#     'owner': {'login': 'Cycorevil',
#      'id': 106861457,
#      'node_id': 'U_kgDOBl6TkQ',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/106861457?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Cycorevil',
#      'html_url': 'https://github.com/Cycorevil',
#      'followers_url': 'https://api.github.com/users/Cycorevil/followers',
#      'following_url': 'https://api.github.com/users/Cycorevil/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Cycorevil/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Cycorevil/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Cycorevil/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Cycorevil/orgs',
#      'repos_url': 'https://api.github.com/users/Cycorevil/repos',
#      'events_url': 'https://api.github.com/users/Cycorevil/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Cycorevil/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/Cycorevil/MUSIC-Video',
#     'description': 'This Is Light And Smooth Music Userbot Made by @The_LegendBoy',
#     'fork': True,
#     'url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video',
#     'forks_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/forks',
#     'keys_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/teams',
#     'hooks_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/hooks',
#     'issue_events_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/events',
#     'assignees_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/tags',
#     'blobs_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/languages',
#     'stargazers_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/stargazers',
#     'contributors_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/contributors',
#     'subscribers_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/subscribers',
#     'subscription_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/subscription',
#     'commits_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/merges',
#     'archive_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/downloads',
#     'issues_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/Cycorevil/MUSIC-Video/deployments',
#     'created_at': '2022-06-04T15:47:45Z',
#     'updated_at': '2022-05-18T19:39:11Z',
#     'pushed_at': '2022-04-17T11:01:20Z',
#     'git_url': 'git://github.com/Cycorevil/MUSIC-Video.git',
#     'ssh_url': 'git@github.com:Cycorevil/MUSIC-Video.git',
#     'clone_url': 'https://github.com/Cycorevil/MUSIC-Video.git',
#     'svn_url': 'https://github.com/Cycorevil/MUSIC-Video',
#     'homepage': None,
#     'size': 1862,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'agpl-3.0',
#      'name': 'GNU Affero General Public License v3.0',
#      'spdx_id': 'AGPL-3.0',
#      'url': 'https://api.github.com/licenses/agpl-3.0',
#      'node_id': 'MDc6TGljZW5zZTE='},
#     'allow_forking': True,
#     'is_template': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710632',
#   'type': 'PushEvent',
#   'actor': {'id': 74659618,
#    'login': 'max-acumen',
#    'display_login': 'max-acumen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/max-acumen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74659618?'},
#   'repo': {'id': 319035705,
#    'name': 'acumenlabs/status-page',
#    'url': 'https://api.github.com/repos/acumenlabs/status-page'},
#   'payload': {'push_id': 10071143992,
#    'size': 4,
#    'distinct_size': 4,
#    'ref': 'refs/heads/master',
#    'head': '93f16a30b79fb9d312e720319400de6c08d8e83d',
#    'before': 'a53a803e59e203294957feed65d37724f458e3d7',
#    'commits': [{'sha': '9d744b3e7aea2b257cb712e5862e5e4625a5399a',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '🟩 Acumen Website is up (200 in 294 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/acumenlabs/status-page/commits/9d744b3e7aea2b257cb712e5862e5e4625a5399a'},
#     {'sha': '8e66174d93cba84d48d530b7cd0452101d6aa497',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '🟩 Acumen API is up (200 in 161 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/acumenlabs/status-page/commits/8e66174d93cba84d48d530b7cd0452101d6aa497'},
#     {'sha': 'a913c8430fa23f60028e9e4b6889d8c041e7cab7',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '🟨 Fetchers is degraded (200 in 144 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/acumenlabs/status-page/commits/a913c8430fa23f60028e9e4b6889d8c041e7cab7'},
#     {'sha': '93f16a30b79fb9d312e720319400de6c08d8e83d',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '🟩 Processors is up (200 in 63 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/acumenlabs/status-page/commits/93f16a30b79fb9d312e720319400de6c08d8e83d'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z',
#   'org': {'id': 52884834,
#    'login': 'acumenlabs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/acumenlabs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52884834?'}},
#  {'id': '22161710631',
#   'type': 'PushEvent',
#   'actor': {'id': 45837,
#    'login': 'sdball',
#    'display_login': 'sdball',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sdball',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45837?'},
#   'repo': {'id': 435317931,
#    'name': 'sdball/advent-of-code',
#    'url': 'https://api.github.com/repos/sdball/advent-of-code'},
#   'payload': {'push_id': 10071143997,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3b117d978af2d295e964ee342276069aa7feb888',
#    'before': '4a34689636dd5be9456370a047f2e5f7f8db95dc',
#    'commits': [{'sha': '3b117d978af2d295e964ee342276069aa7feb888',
#      'author': {'email': 'sdball@gmail.com', 'name': 'Stephen Ball'},
#      'message': 'Add "Run in Livebook" badge',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sdball/advent-of-code/commits/3b117d978af2d295e964ee342276069aa7feb888'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710614',
#   'type': 'PushEvent',
#   'actor': {'id': 48135649,
#    'login': 'Nilstrieb',
#    'display_login': 'Nilstrieb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nilstrieb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48135649?'},
#   'repo': {'id': 410298610,
#    'name': 'Nilstrieb/rust',
#    'url': 'https://api.github.com/repos/Nilstrieb/rust'},
#   'payload': {'push_id': 10071143985,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/data-structures-ub',
#    'head': '7e3bee6d8ecf2bd1270b99ea1425f594d6adaf54',
#    'before': '9fef644e7e5a5ded13ffefc35e80500c5769badd',
#    'commits': [{'sha': 'fc8b13cb96a5b45bb7028ca0f50d1444f0f95582',
#      'author': {'email': '48135649+Nilstrieb@users.noreply.github.com',
#       'name': 'Nilstrieb'},
#      'message': "Adapt rustc_data_structures tests to run in strict miri\n\nSome tests took too long and owning_ref is fundamentally flawed,\nso don't run these tests or run them with a shorter N. This makes\nmiri with `-Zmiri-strict-provenance` usable to find UB.",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Nilstrieb/rust/commits/fc8b13cb96a5b45bb7028ca0f50d1444f0f95582'},
#     {'sha': '7e3bee6d8ecf2bd1270b99ea1425f594d6adaf54',
#      'author': {'email': '48135649+Nilstrieb@users.noreply.github.com',
#       'name': 'Nilstrieb'},
#      'message': 'Fix stacked borrows invalidation in rustc_data_structures sip128\n\nIt creates the src pointer first, which is then invalidated by a\nunique borrow of the destination pointer. Swap the borrows around\nto fix this. Found with miri.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Nilstrieb/rust/commits/7e3bee6d8ecf2bd1270b99ea1425f594d6adaf54'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710611',
#   'type': 'PushEvent',
#   'actor': {'id': 45474750,
#    'login': 'narutozb',
#    'display_login': 'narutozb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/narutozb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45474750?'},
#   'repo': {'id': 476390064,
#    'name': 'narutozb/StudyZALE',
#    'url': 'https://api.github.com/repos/narutozb/StudyZALE'},
#   'payload': {'push_id': 10071143988,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e28beb2b1be436ce77abd9cb322624d59f7b8d14',
#    'before': '2f789a98801f3b334acf7a29d5ca2dc2764f4dd5',
#    'commits': [{'sha': 'e28beb2b1be436ce77abd9cb322624d59f7b8d14',
#      'author': {'email': 'narutozb@hotmail.com', 'name': 'narutozb'},
#      'message': '导航栏说明',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/narutozb/StudyZALE/commits/e28beb2b1be436ce77abd9cb322624d59f7b8d14'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710619',
#   'type': 'CreateEvent',
#   'actor': {'id': 56177521,
#    'login': 'ezhu010',
#    'display_login': 'ezhu010',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ezhu010',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56177521?'},
#   'repo': {'id': 499869424,
#    'name': 'ezhu010/backend',
#    'url': 'https://api.github.com/repos/ezhu010/backend'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710603',
#   'type': 'PushEvent',
#   'actor': {'id': 94976661,
#    'login': 'NAJI2329',
#    'display_login': 'NAJI2329',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NAJI2329',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94976661?'},
#   'repo': {'id': 497061508,
#    'name': 'NAJI2329/PreLabTech-NFT-Marketplace',
#    'url': 'https://api.github.com/repos/NAJI2329/PreLabTech-NFT-Marketplace'},
#   'payload': {'push_id': 10071143980,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': 'ef77fbac3f18dea839ea80f4d1217e65d125c946',
#    'before': '43069c3a520d75bc52821a0b1f284f5a75e18e88',
#    'commits': [{'sha': 'f787e62827fdf7ed12a1adea47bb0ce7f285117a',
#      'author': {'email': 'be1512t6@gmail.com', 'name': 'NAJI2329'},
#      'message': 'remove "view NFT" in the collection',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/NAJI2329/PreLabTech-NFT-Marketplace/commits/f787e62827fdf7ed12a1adea47bb0ce7f285117a'},
#     {'sha': 'ef77fbac3f18dea839ea80f4d1217e65d125c946',
#      'author': {'email': 'be1512t6@gmail.com', 'name': 'NAJI2329'},
#      'message': 'add buy Modal',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/NAJI2329/PreLabTech-NFT-Marketplace/commits/ef77fbac3f18dea839ea80f4d1217e65d125c946'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710592',
#   'type': 'PushEvent',
#   'actor': {'id': 87618423,
#    'login': 'bsc-predict',
#    'display_login': 'bsc-predict',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bsc-predict',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/87618423?'},
#   'repo': {'id': 394094643,
#    'name': 'bsc-predict/bsc-predict-updater',
#    'url': 'https://api.github.com/repos/bsc-predict/bsc-predict-updater'},
#   'payload': {'push_id': 10071143982,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '4bdd257607e6fe0e131c47672d64e16da051960e',
#    'before': '45ce254ce05de12733a6622f07cc2bc972f61916',
#    'commits': [{'sha': '4bdd257607e6fe0e131c47672d64e16da051960e',
#      'author': {'email': 'contact@bscpredict.com', 'name': 'bsc-predict'},
#      'message': 'update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bsc-predict/bsc-predict-updater/commits/4bdd257607e6fe0e131c47672d64e16da051960e'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710629',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 1174092,
#    'login': 'franky47',
#    'display_login': 'franky47',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/franky47',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1174092?'},
#   'repo': {'id': 431477743,
#    'name': '47ng/prisma-field-encryption',
#    'url': 'https://api.github.com/repos/47ng/prisma-field-encryption'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/47ng/prisma-field-encryption/issues/24',
#     'repository_url': 'https://api.github.com/repos/47ng/prisma-field-encryption',
#     'labels_url': 'https://api.github.com/repos/47ng/prisma-field-encryption/issues/24/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/47ng/prisma-field-encryption/issues/24/comments',
#     'events_url': 'https://api.github.com/repos/47ng/prisma-field-encryption/issues/24/events',
#     'html_url': 'https://github.com/47ng/prisma-field-encryption/issues/24',
#     'id': 1251851856,
#     'node_id': 'I_kwDOGbfT785Knb5Q',
#     'number': 24,
#     'title': 'Use Case: PII Personal Identifiable Information - Right to be Forgotten - Prisma Encryption',
#     'user': {'login': 'D1no',
#      'id': 2397125,
#      'node_id': 'MDQ6VXNlcjIzOTcxMjU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/2397125?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/D1no',
#      'html_url': 'https://github.com/D1no',
#      'followers_url': 'https://api.github.com/users/D1no/followers',
#      'following_url': 'https://api.github.com/users/D1no/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/D1no/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/D1no/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/D1no/subscriptions',
#      'organizations_url': 'https://api.github.com/users/D1no/orgs',
#      'repos_url': 'https://api.github.com/users/D1no/repos',
#      'events_url': 'https://api.github.com/users/D1no/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/D1no/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2022-05-29T10:40:01Z',
#     'updated_at': '2022-06-04T15:47:46Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': 'Hi, thank you for creating this library! I would like to provide GDPR / „right to be forgotten“ assurance while keeping schema flexibility. One way for that is [pseudomization](https://en.wikipedia.org/wiki/Pseudonymization) where each user has an assigned description key; when that is deleted, all data of that user is useless but doesn’t require propagating deletes.\r\n\r\nI was wondering how you would handle that architecture and if `prisma-field-encryption` would be a valid solution approach. Naturally I‘d try to push this further down to DB level (i.e. the with the [PostgreSOL Anonymizer](https://postgresql-anonymizer.readthedocs.io/en/stable/)) but that seems to take flexibility out schema management (requiring raw queries?).\r\n\r\nI‘m in the concept phase, everything should be azure and end-to-end typescript. Regarding stack, prisma & co still investigating. \r\n\r\nThank you very much!\r\n\r\nPS: A data science team needs to also be able to access encrypted information without going through the GraphQL API. So being able to decrypt data outside of `prisma-field-encryption` is useful and seems to be already on the map when reading this https://github.com/47ng/prisma-field-encryption/issues/12#issuecomment-1043686549',
#     'reactions': {'url': 'https://api.github.com/repos/47ng/prisma-field-encryption/issues/24/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/47ng/prisma-field-encryption/issues/24/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/47ng/prisma-field-encryption/issues/comments/1146638564',
#     'html_url': 'https://github.com/47ng/prisma-field-encryption/issues/24#issuecomment-1146638564',
#     'issue_url': 'https://api.github.com/repos/47ng/prisma-field-encryption/issues/24',
#     'id': 1146638564,
#     'node_id': 'IC_kwDOGbfT785EWFDk',
#     'user': {'login': 'franky47',
#      'id': 1174092,
#      'node_id': 'MDQ6VXNlcjExNzQwOTI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1174092?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/franky47',
#      'html_url': 'https://github.com/franky47',
#      'followers_url': 'https://api.github.com/users/franky47/followers',
#      'following_url': 'https://api.github.com/users/franky47/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/franky47/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/franky47/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/franky47/subscriptions',
#      'organizations_url': 'https://api.github.com/users/franky47/orgs',
#      'repos_url': 'https://api.github.com/users/franky47/repos',
#      'events_url': 'https://api.github.com/users/franky47/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/franky47/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2022-06-04T15:47:45Z',
#     'updated_at': '2022-06-04T15:47:45Z',
#     'author_association': 'MEMBER',
#     'body': "I see, so if you were to use one key per row, and delete that key, you'd essentially end up with unreadable data for the PII fields, while preserving metadata (cleartext columns and foreign key connections).\n\nThis library does not provide this out of the box (it uses a single key for all encryption operations), but we're working on adding the ability to do custom ciphers in #23, which could be an entry point for your use-case.\n\nI suppose it would need to provide context data to the cipher function to guide key management.",
#     'reactions': {'url': 'https://api.github.com/repos/47ng/prisma-field-encryption/issues/comments/1146638564/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z',
#   'org': {'id': 43356325,
#    'login': '47ng',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/47ng',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43356325?'}},
#  {'id': '22161710630',
#   'type': 'DeleteEvent',
#   'actor': {'id': 12647725,
#    'login': 'yim-lee',
#    'display_login': 'yim-lee',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yim-lee',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12647725?'},
#   'repo': {'id': 493455819,
#    'name': 'yim-lee/swift-distributed-actors',
#    'url': 'https://api.github.com/repos/yim-lee/swift-distributed-actors'},
#   'payload': {'ref': 'iss935', 'ref_type': 'branch', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710615',
#   'type': 'CreateEvent',
#   'actor': {'id': 106874047,
#    'login': 'Buhrut',
#    'display_login': 'Buhrut',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Buhrut',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/106874047?'},
#   'repo': {'id': 499869425,
#    'name': 'Buhrut/my_first_project',
#    'url': 'https://api.github.com/repos/Buhrut/my_first_project'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710583',
#   'type': 'PushEvent',
#   'actor': {'id': 106601228,
#    'login': 'uqhs7ja',
#    'display_login': 'uqhs7ja',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/uqhs7ja',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/106601228?'},
#   'repo': {'id': 498342586,
#    'name': 'uqhs7ja/sa',
#    'url': 'https://api.github.com/repos/uqhs7ja/sa'},
#   'payload': {'push_id': 10071143965,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/bd47d0f464d9bf8ea863',
#    'head': '1ab44cc35f7ebb86ae04a4e0be091889633f9f8f',
#    'before': '5a1f20a0392270573f689d4acc7a386124d75664',
#    'commits': [{'sha': 'd7262f7dfcfcdbfade572bbfe7785767338632e9',
#      'author': {'email': 'chriskm0116@gmail.com', 'name': 'Arlentak'},
#      'message': 'Modify tracked file during workflow',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/uqhs7ja/sa/commits/d7262f7dfcfcdbfade572bbfe7785767338632e9'},
#     {'sha': 'fc46fe52ec5884c07b1818c380033dafd0a7e5c7',
#      'author': {'email': 'chriskm0116@gmail.com', 'name': 'Arlentak'},
#      'message': 'Add untracked file during workflow',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/uqhs7ja/sa/commits/fc46fe52ec5884c07b1818c380033dafd0a7e5c7'},
#     {'sha': '1ab44cc35f7ebb86ae04a4e0be091889633f9f8f',
#      'author': {'email': 'uqhs7ja@users.noreply.github.com',
#       'name': 'uqhs7ja'},
#      'message': '[create-pull-request] automated change',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/uqhs7ja/sa/commits/1ab44cc35f7ebb86ae04a4e0be091889633f9f8f'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710578',
#   'type': 'PushEvent',
#   'actor': {'id': 103153661,
#    'login': 'tmelo12',
#    'display_login': 'tmelo12',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tmelo12',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103153661?'},
#   'repo': {'id': 499863338,
#    'name': 'tmelo12/create-plan-total',
#    'url': 'https://api.github.com/repos/tmelo12/create-plan-total'},
#   'payload': {'push_id': 10071143979,
#    'size': 4,
#    'distinct_size': 1,
#    'ref': 'refs/heads/thiago',
#    'head': '7e3ba203d572eca90990e636f3acbc26a2889863',
#    'before': '79e73d0bb4f7e1c01c5028f108b536401e5ca28f',
#    'commits': [{'sha': '93db028fc0151b82c471726cccea9f2326fc9ceb',
#      'author': {'email': 'thiagomelo@super.ufam.edu.br',
#       'name': 'Thiago Melo'},
#      'message': "Merge branch 'thiago'",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/tmelo12/create-plan-total/commits/93db028fc0151b82c471726cccea9f2326fc9ceb'},
#     {'sha': '7c30094c12f158baef07ae464d3ec1ee6a17471e',
#      'author': {'email': 'thiagomelo@super.ufam.edu.br',
#       'name': 'Thiago Melo'},
#      'message': 'leitura de configuracoes',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/tmelo12/create-plan-total/commits/7c30094c12f158baef07ae464d3ec1ee6a17471e'},
#     {'sha': '75cebba4360a1ec69345fa8c06a510fa770aaf4e',
#      'author': {'email': 'thiagomelo@super.ufam.edu.br',
#       'name': 'Thiago Melo'},
#      'message': "Merge branch 'thiago'",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/tmelo12/create-plan-total/commits/75cebba4360a1ec69345fa8c06a510fa770aaf4e'},
#     {'sha': '7e3ba203d572eca90990e636f3acbc26a2889863',
#      'author': {'email': 'thiagomelo@super.ufam.edu.br',
#       'name': 'Thiago Melo'},
#      'message': 'teste commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tmelo12/create-plan-total/commits/7e3ba203d572eca90990e636f3acbc26a2889863'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710568',
#   'type': 'PushEvent',
#   'actor': {'id': 1612612,
#    'login': 'bomeara',
#    'display_login': 'bomeara',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bomeara',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1612612?'},
#   'repo': {'id': 499568949,
#    'name': 'bomeara/treebasestatic',
#    'url': 'https://api.github.com/repos/bomeara/treebasestatic'},
#   'payload': {'push_id': 10071143976,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '20b985e07aa250585e0ad4c15cb3a5714552cb86',
#    'before': 'd8ea8f2c9d4564f103cc3172020b0e5fecff064e',
#    'commits': [{'sha': '20b985e07aa250585e0ad4c15cb3a5714552cb86',
#      'author': {'email': 'omeara.brian@gmail.com', 'name': "Brian O'Meara"},
#      'message': 'added study',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bomeara/treebasestatic/commits/20b985e07aa250585e0ad4c15cb3a5714552cb86'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710580',
#   'type': 'PushEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 383988328,
#    'name': 'joshbolduc/vscode-story-explorer',
#    'url': 'https://api.github.com/repos/joshbolduc/vscode-story-explorer'},
#   'payload': {'push_id': 10071143972,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dependabot/npm_and_yarn/types/lodash-4.14.182',
#    'head': '4414ac6f621ab4c7ca0027b8b6d6d6ded9c6d49d',
#    'before': 'fd3b0482d7c97fe9d198bdf3d02e22df8fa0c79d',
#    'commits': [{'sha': '297c8ef4eba31f231defe148266cf73cb6878b85',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'chore(deps): bump simple-get from 3.1.0 to 3.1.1\n\nBumps [simple-get](https://github.com/feross/simple-get) from 3.1.0 to 3.1.1.\n- [Release notes](https://github.com/feross/simple-get/releases)\n- [Commits](https://github.com/feross/simple-get/compare/v3.1.0...v3.1.1)\n\n---\nupdated-dependencies:\n- dependency-name: simple-get\n  dependency-type: indirect\n...\n\nSigned-off-by: dependabot[bot] <support@github.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/joshbolduc/vscode-story-explorer/commits/297c8ef4eba31f231defe148266cf73cb6878b85'},
#     {'sha': '4414ac6f621ab4c7ca0027b8b6d6d6ded9c6d49d',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'chore(deps-dev): bump @types/lodash from 4.14.177 to 4.14.182\n\nBumps [@types/lodash](https://github.com/DefinitelyTyped/DefinitelyTyped/tree/HEAD/types/lodash) from 4.14.177 to 4.14.182.\n- [Release notes](https://github.com/DefinitelyTyped/DefinitelyTyped/releases)\n- [Commits](https://github.com/DefinitelyTyped/DefinitelyTyped/commits/HEAD/types/lodash)\n\n---\nupdated-dependencies:\n- dependency-name: "@types/lodash"\n  dependency-type: direct:development\n  update-type: version-update:semver-patch\n...\n\nSigned-off-by: dependabot[bot] <support@github.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/joshbolduc/vscode-story-explorer/commits/4414ac6f621ab4c7ca0027b8b6d6d6ded9c6d49d'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710573',
#   'type': 'CreateEvent',
#   'actor': {'id': 13964919,
#    'login': 'abyshekhar',
#    'display_login': 'abyshekhar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/abyshekhar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13964919?'},
#   'repo': {'id': 499869404,
#    'name': 'abyshekhar/nextjs-comment-system',
#    'url': 'https://api.github.com/repos/abyshekhar/nextjs-comment-system'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710593',
#   'type': 'PushEvent',
#   'actor': {'id': 40485962,
#    'login': 'Shoroxi',
#    'display_login': 'Shoroxi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Shoroxi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40485962?'},
#   'repo': {'id': 499467433,
#    'name': 'Shoroxi/Telegram_bots',
#    'url': 'https://api.github.com/repos/Shoroxi/Telegram_bots'},
#   'payload': {'push_id': 10071143981,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd7906ac83043c5446e47ed0c301e30541a6735c4',
#    'before': '24d73b85629e0b2c5f60fb39007cbd7e9a3b9a05',
#    'commits': [{'sha': 'd7906ac83043c5446e47ed0c301e30541a6735c4',
#      'author': {'email': '40485962+Shoroxi@users.noreply.github.com',
#       'name': 'Шкарупа Глеб'},
#      'message': 'Delete DZ_bot/states/__pycache__ directory',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Shoroxi/Telegram_bots/commits/d7906ac83043c5446e47ed0c301e30541a6735c4'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710566',
#   'type': 'PushEvent',
#   'actor': {'id': 105630721,
#    'login': 'jakegreen4587',
#    'display_login': 'jakegreen4587',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jakegreen4587',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/105630721?'},
#   'repo': {'id': 492730015,
#    'name': 'jakegreen4587/1',
#    'url': 'https://api.github.com/repos/jakegreen4587/1'},
#   'payload': {'push_id': 10071143961,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd4b0b7ff0debee26f4e9112660db21e143212b1f',
#    'before': '6ca3867b2e2cbe5023cee51ec9e4a1fe26716a9d',
#    'commits': [{'sha': 'd4b0b7ff0debee26f4e9112660db21e143212b1f',
#      'author': {'email': 'test@gmail.com', 'name': 'test'},
#      'message': 'test',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jakegreen4587/1/commits/d4b0b7ff0debee26f4e9112660db21e143212b1f'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'},
#  {'id': '22161710557',
#   'type': 'CreateEvent',
#   'actor': {'id': 75322794,
#    'login': 'Hawk1430',
#    'display_login': 'Hawk1430',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Hawk1430',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/75322794?'},
#   'repo': {'id': 499869423,
#    'name': 'Hawk1430/Striver-60-Days-SDE-Sheet-Challenge',
#    'url': 'https://api.github.com/repos/Hawk1430/Striver-60-Days-SDE-Sheet-Challenge'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': '60 Days Challenge',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-06-04T15:47:45Z'},
#  {'id': '22161710567',
#   'type': 'PushEvent',
#   'actor': {'id': 394382,
#    'login': 'bep',
#    'display_login': 'bep',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bep',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/394382?'},
#   'repo': {'id': 11180687,
#    'name': 'gohugoio/hugo',
#    'url': 'https://api.github.com/repos/gohugoio/hugo'},
#   'payload': {'push_id': 10071143774,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '311b8008bfba3411741ef8ebe4b094adb92ce041',
#    'before': 'c7d5f9f067fd6a37ac6b75cb1c02259debd3ff21',
#    'commits': [{'sha': '311b8008bfba3411741ef8ebe4b094adb92ce041',
#      'author': {'email': 'bjorn.erik.pedersen@gmail.com',
#       'name': 'Bjørn Erik Pedersen'},
#      'message': 'helpers: Fix panic with invalid defaultMarkdownHandler\n\nFixes #9968',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/gohugoio/hugo/commits/311b8008bfba3411741ef8ebe4b094adb92ce041'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z',
#   'org': {'id': 29385237,
#    'login': 'gohugoio',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/gohugoio',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29385237?'}},
#  {'id': '22161710561',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 86929735,
#    'name': 'Lombiq/Orchard',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard'},
#   'payload': {'push_id': 10071143971,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/feature/asynccache',
#    'head': '8aa84ef0481fbb90cc4a8b1c0635df74a8a9aec7',
#    'before': '8aa84ef0481fbb90cc4a8b1c0635df74a8a9aec7',
#    'commits': []},
#   'public': True,
#   'created_at': '2022-06-04T15:47:45Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '22161710546',
#   'type': 'PushEvent',
#   'actor': {'id': 40918737,
#    'login': 'donaldsouza',
#    'display_login': 'donaldsouza',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/donaldsouza',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40918737?'},
#   'repo': {'id': 240272766,
#    'name': 'donaldsouza/current-date',
#    'url': 'https://api.github.com/repos/donaldsouza/current-date'},
#   'payload': {'push_id': 10071143964,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '69bf9a930814c706a684a325f4d74c3eb1356551',
#    'before': 'a4dcdf480ae25310fabbe66400395bebd74e8958',
#    'commits': [{'sha': '69bf9a930814c706a684a325f4d74c3eb1356551',
#      'author': {'email': '40918737+donaldsouza@users.noreply.github.com',
#       'name': 'donaldsouza'},
#      'message': 'message_2022-06-04T15:47:44',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/donaldsouza/current-date/commits/69bf9a930814c706a684a325f4d74c3eb1356551'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:45Z'},
#  {'id': '22161710571',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 317399297,
#    'name': 'Heccubernny/heccubernny',
#    'url': 'https://api.github.com/repos/Heccubernny/heccubernny'},
#   'payload': {'push_id': 10071143974,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '24e5f63ba7419334d287e66aef40819116d86d40',
#    'before': '81043b77ccd2e2b3142ea737ae73aaf9a1866696',
#    'commits': [{'sha': '24e5f63ba7419334d287e66aef40819116d86d40',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'GitHub Actions'},
#      'message': 'Automated Coding Activity Update :alien:',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Heccubernny/heccubernny/commits/24e5f63ba7419334d287e66aef40819116d86d40'}]},
#   'public': True,
#   'created_at': '2022-06-04T15:47:46Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.27.1',
#   'X-Amzn-Trace-Id': 'Root=1-629b7fe0-21110f487bdb180b565255ea'},
#  'origin': '59.115.195.43',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.27.1',
#   'X-Amzn-Trace-Id': 'Root=1-629b7feb-2570a1cc379a8a801bb3c60d'},
#  'json': None,
#  'origin': '59.115.195.43',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.27.1',
#   'X-Amzn-Trace-Id': 'Root=1-629b7ff4-4c58bb60070a687b78f2c520'},
#  'json': None,
#  'origin': '59.115.195.43',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
